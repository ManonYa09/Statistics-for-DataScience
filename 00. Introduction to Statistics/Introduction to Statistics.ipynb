# %% [markdown]
# ![mathsandstat.jpeg](attachment:mathsandstat.jpeg)![ds1.png](attachment:ds1.png)

# %% [markdown]
# ### We'll learn in this Statistics course:
#
# - Descriptive Statistcs
# - Inferential statistics
#     - Advance method like
#         - Confident inteval
#         - Hypothesis testing
#         - Regresstion
#         - Classification

# %% [markdown]
# **Qualitative variable:** are variable that have distinct categories according to some characteristics or attribute. Example: Country, Gender, Favorite, Color,etc.
# **Quantitative variable** are variable that can b counted or measured.

# %% [markdown]
# ## Exercise
# ### qualitative or quantitative.
# 1. Sizes of soft drinks sold by a fast-food restaurant (small, medium, and large)
#
# 2. Pizza sizes (small, medium, and large)
#
# 3. Cholesterol counts for individuals.

# %% [markdown]
# <img src="Photos/.png" alt="Control Structure" width="60%" style="display: block; margin: 0 auto;">

# %% [markdown]
# ![typesofvariables.gif](attachment:typesofvariables.gif)

# %% [markdown]
# ## What is Descriptive Statistics?
# -  consists of the collection, organization, summarization and presentation of data.

# %% [markdown]
# ## What is Inferential Statistics?
# - consists of generalizing from samples to populations, performing estimations and hypothesis tests, determining relationships among variables, and making predictions.

# %% [markdown]
# ## Learning agenda of this notebook
# 1. Data and its Types
# 2. Collection of Data (Population vs Sample)
# 3. Overview of Statistics and its Types
# 4. Descriptive Statistics: Measure of Central Tendency
#     - Mean
#     - Median
#     - Mode
# 5. Descriptive Statistics: Measure of Spread
#     - Range
#     - IQR
#     - Variance
#     - Standard Deviation
# 6. Descriptive Statistics: Measure of Asymmetry
#     - Skewness
#     - Kurtosis
# 7. Analysis Strategy
# 8. Example Datasets
# 9. Univariate Analysis and Data Visualization
# 10. Bivariate Analysis and Data Visualization

# %% [markdown]
# # 1. Data and its Types

# %% [markdown]
# ![titanic.png](attachment:titanic.png)

# %% [markdown]
# # 4. Descriptive Statistics: Measures of Center

# %%
data = [12, 15, 18, 20, 22, 25, 28, 30]

# %%
toltal (number)/ number of

# %%
import statistics

# %% [markdown]
# Example 1

# %%
data1 = [14000, 19000, 16000, 20000, 15000, 16000, 15000, 15000, 22000]
print("mean(data1): %.2f" % statistics.mean(data1))
print("median(data1): ", statistics.median(data1))
print("mode(data1): ", statistics.mode(data1))
# Out:
# mean(data1): 16888.89
# median(data1):  16000
# mode(data1):  15000

# %% [markdown]
# Example 2

# %%
data2 = [14000, 19000, 16000, 20000, 15000, 16000, 15000, 15000, 22000, 900000]
print("mean of data 2: %.2f" % statistics.mean(data2))
# Out:
# mean of data 2: 105200.00
